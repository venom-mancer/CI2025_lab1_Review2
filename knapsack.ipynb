# %% [markdown]
# Copyright **`(c)`** 2025 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
import numpy as np
from icecream import ic

# %%
class Solution:

    def __init__(self, n_knapsacks, n_items, n_dimensions, values, weights, constraints, rng):
        self.n_knapsacks = n_knapsacks
        self.n_items = n_items
        self.n_dimensions = n_dimensions
        self.values = values
        self.weights = weights
        self.constraints = constraints
        self.rng = rng

    def is_valid(self, solution):
        # Check that no item appears in multiple knapsacks
        if not np.all(solution.sum(axis=0) <= 1):
            return False

        # Check constraint violations for each knapsack
        for k in range(self.n_knapsacks):
            items_in_knapsack = solution[k]
            
            # Only check if knapsack has items
            if np.any(items_in_knapsack):
                total_weight = self.weights[items_in_knapsack].sum(axis=0)
                if np.any(total_weight > self.constraints[k]):
                    return False

        return True

    def fitness(self, solution):
        #we assume the solution to be already validated, we do not call is_valid in this function
        return np.sum(self.values*solution) #total value of items in all knapsacks

    def tweak(self, solution):
        #idea: pick a random knapsack and item, flip their state and repeat the process n times. n is correlated to the ratio between the  assigned items and the total ones. If the ratio is low, a lot of items still have to be assigned, so we pick more knapsack and more items. Otherwise, less elements are selected
        tot_assigned = solution.sum()
        ratio = tot_assigned /self.n_items

        if ratio < 0.1:
            n = self.rng.integers(3,8)
        elif ratio < 0.3:
            n = self.rng.integers(2,5)
        else:
            n = self.rng.integers(1,3)


        for _ in range(n):
            k = self.rng.integers(0, self.n_knapsacks) #select a knapsack
            i = self.rng.integers(0, self.n_items)    #select an item
            
            if solution[k,i]:
                #item is in this knapsack --> remove it
                solution[k,i] = False
            else:
                if not np.any(solution[:,i]): #solution not in any other knapsack
                    solution[k,i] = True
                else: #is in another knapsack
                    current_knapsack = np.where(solution[:,i])[0][0] #get the knapsack where the item is currently in
                    solution[current_knapsack, i] = False #remove from this knapsack
                    solution[k,i] = True #add to new knapsack
            
        return solution
    


    def make_valid(self, solution):

        #try to make the solution valid (non valid solution are allowed, either for the initial state or intermiediate one)
        while(not self.is_valid(solution)):
            duplicates = np.where(solution.sum(axis=0)>1)[0] #for initial state, try to remove duplicates
            if len(duplicates) > 0:
                for item in duplicates:
                    knapsack_w_i = np.where(solution[:, item])[0] #get all knapsacks that have the duplicated item
                    for k in knapsack_w_i[1:]: #remove the item from all the other knapsacks
                        solution[k, item] = False
                    
            violating_k = []

            for k in range (self.n_knapsacks):  #try to find all the knapsacks that are violating constraints
                if np.any(self.weights[solution[k]].sum(axis = 0) > self.constraints[k]):
                    violating_k.append(k)

            if not violating_k:
                break
            
            for k in violating_k:
                num_items = np.where(solution[k] == True)[0] #get items that are in the knapsack k

                if len(num_items )> 0:
                    n_items_to_remove = self.rng.integers(1, len(num_items)) #select a random number of items to remove from knapsack that violates constraints
                    items_to_remove = self.rng.choice(num_items, size = n_items_to_remove, replace = False)

                    for i in items_to_remove:
                        solution[k, i] = False #remove items from knapsack

        return solution
    
    def resolve(self, max_iter = 1000):
        solution = np.array([np.random.random(self.n_items) < 0.5 for _ in range(self.n_knapsacks)], dtype=bool) #random sol
        
        solution = self.make_valid(solution)
        
        best_fitness = self.fitness(solution)
        best_solution = solution.copy()
        

        for _ in range(max_iter):
            current_sol = self.make_valid(self.tweak(best_solution.copy()))
            
            current_fitness = self.fitness(current_sol)

            if(current_fitness > best_fitness):
                best_solution = current_sol.copy()
                best_fitness = current_fitness
                ic(best_fitness)

        return best_solution, best_fitness

# %% [markdown]
# ## TEST PROBLEMS

# %%
# Problem 1:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 3
NUM_ITEMS = 20
NUM_DIMENSIONS = 2
VALUES = rng.integers(0, 100, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 100, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(
    0, 100 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS, NUM_DIMENSIONS)
)

# %%
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS, rng)
solution, fitness = solver.resolve(max_iter=10000)
solver.is_valid(solution)
# Out:
# ic| best_fitness: np.int64(603)
# ic| best_fitness: np.int64(676)
# ic| best_fitness: np.int64(773)
# ic| best_fitness: np.int64(816)
# ic| best_fitness: np.int64(892)
# ic| best_fitness: np.int64(901)
# ic| best_fitness: np.int64(921)
# ic| best_fitness: np.int64(929)
# ic| best_fitness: np.int64(1000)
# ic| best_fitness: np.int64(1012)
# ic| best_fitness: np.int64(1020)
# ic| best_fitness: np.int64(1045)
# ic| best_fitness: np.int64(1048)
# ic| best_fitness: np.int64(1056)
# True

# %%
# Problem 2:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 10
NUM_ITEMS = 100
NUM_DIMENSIONS = 10
VALUES = rng.integers(0, 1000, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 1000, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(
    1000 * 2, 1000 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS, NUM_DIMENSIONS)
)

# %%
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS, rng)
solution, fitness = solver.resolve(max_iter=25000)
solver.is_valid(solution)
# Out:
# ic| best_fitness: np.int64(15096)
# ic| best_fitness: np.int64(16454)
# ic| best_fitness: np.int64(17460)
# ic| best_fitness: np.int64(18096)
# ic| best_fitness: np.int64(19041)
# ic| best_fitness: np.int64(19267)
# ic| best_fitness: np.int64(19736)
# ic| best_fitness: np.int64(20494)
# ic| best_fitness: np.int64(20857)
# ic| best_fitness: np.int64(21414)
# ic| best_fitness: np.int64(22195)
# ic| best_fitness: np.int64(23117)
# ic| best_fitness: np.int64(24595)
# ic| best_fitness: np.int64(25453)
# ic| best_fitness: np.int64(26008)
# ic| best_fitness: np.int64(26453)
# ic| best_fitness: np.int64(26863)
# ic| best_fitness: np.int64(27057)
# ic| best_fitness: np.int64(28073)
# ic| best_fitness: np.int64(28806)
# ic| best_fitness: np.int64(28898)
# ic| best_fitness: np.int64(28975)
# ic| best_fitness: np.int64(29430)
# ic| best_fitness: np.int64(29742)
# ic| best_fitness: np.int64(29785)
# ic| best_fitness: np.int64(30626)
# ic| best_fitness: np.int64(30827)
# ic| best_fitness: np.int64(31895)
# ic| best_fitness: np.int64(32690)
# ic| best_fitness: np.int64(33434)
# ic| best_fitness: np.int64(33497)
# ic| best_fitness: np.int64(33887)
# ic| best_fitness: np.int64(34026)
# ic| best_fitness: np.int64(34102)
# ic| best_fitness: np.int64(35077)
# ic| best_fitness: np.int64(35144)
# ic| best_fitness: np.int64(35891)
# ic| best_fitness: np.int64(36000)
# ic| best_fitness: np.int64(36437)
# ic| best_fitness: np.int64(36934)
# ic| best_fitness: np.int64(36979)
# ic| best_fitness: np.int64(37309)
# ic| best_fitness: np.int64(38026)
# ic| best_fitness: np.int64(38123)
# ic| best_fitness: np.int64(38344)
# ic| best_fitness: np.int64(39251)
# ic| best_fitness: np.int64(40156)
# ic| best_fitness: np.int64(40701)
# ic| best_fitness: np.int64(40928)
# ic| best_fitness: np.int64(41291)
# ic| best_fitness: np.int64(41726)
# ic| best_fitness: np.int64(42066)
# ic| best_fitness: np.int64(42195)
# ic| best_fitness: np.int64(42520)
# ic| best_fitness: np.int64(42535)
# ic| best_fitness: np.int64(42754)
# ic| best_fitness: np.int64(42871)
# ic| best_fitness: np.int64(43320)
# ic| best_fitness: np.int64(43445)
# ic| best_fitness: np.int64(43597)
# ic| best_fitness: np.int64(43927)
# ic| best_fitness: np.int64(44030)
# ic| best_fitness: np.int64(44318)
# ic| best_fitness: np.int64(44415)
# ic| best_fitness: np.int64(44430)
# ic| best_fitness: np.int64(44554)
# ic| best_fitness: np.int64(44957)
# ic| best_fitness: np.int64(45323)
# ic| best_fitness: np.int64(45599)
# ic| best_fitness: np.int64(45643)
# ic| best_fitness: np.int64(46118)
# ic| best_fitness: np.int64(46122)
# ic| best_fitness: np.int64(46560)
# ic| best_fitness: np.int64(46627)
# ic| best_fitness: np.int64(46881)
# ic| best_fitness: np.int64(46944)
# ic| best_fitness: np.int64(47167)
# ic| best_fitness: np.int64(47393)
# True

# %%
# Problem 3:
rng = np.random.default_rng(seed=42)
NUM_KNAPSACKS = 100
NUM_ITEMS = 5000
NUM_DIMENSIONS = 100
VALUES = rng.integers(0, 1000, size=NUM_ITEMS)
WEIGHTS = rng.integers(0, 1000, size=(NUM_ITEMS, NUM_DIMENSIONS))
CONSTRAINTS = rng.integers(
    1000 * 10, 1000 * 2 * NUM_ITEMS // NUM_KNAPSACKS, size=(NUM_KNAPSACKS, NUM_DIMENSIONS)
)

# %%
solver = Solution(NUM_KNAPSACKS, NUM_ITEMS, NUM_DIMENSIONS, VALUES, WEIGHTS, CONSTRAINTS, rng)
solution, fitness = solver.resolve(max_iter=50000)
solver.is_valid(solution)
# Out:
# ic| best_fitness: np.int64(64794)
# ic| best_fitness: np.int64(67027)
# ic| best_fitness: np.int64(69503)
# ic| best_fitness: np.int64(72115)
# ic| best_fitness: np.int64(74630)
# ic| best_fitness: np.int64(78953)
# ic| best_fitness: np.int64(81416)
# ic| best_fitness: np.int64(84191)
# ic| best_fitness: np.int64(86979)
# ic| best_fitness: np.int64(89807)
# ic| best_fitness: np.int64(91548)
# ic| best_fitness: np.int64(94104)
# ic| best_fitness: np.int64(95837)
# ic| best_fitness: np.int64(98424)
# ic| best_fitness: np.int64(99787)
# ic| best_fitness: np.int64(101836)
# ic| best_fitness: np.int64(103513)
# ic| best_fitness: np.int64(105168)
# ic| best_fitness: np.int64(108357)
# ic| best_fitness: np.int64(110581)
# ic| best_fitness: np.int64(112928)
# ic| best_fitness: np.int64(115906)
# ic| best_fitness: np.int64(117647)
# ic| best_fitness: np.int64(119943)
# ic| best_fitness: np.int64(124387)
# ic| best_fitness: np.int64(127981)
# ic| best_fitness: np.int64(131039)
# ic| best_fitness: np.int64(132645)
# ic| best_fitness: np.int64(136318)
# ic| best_fitness: np.int64(139805)
# ic| best_fitness: np.int64(142187)
# ic| best_fitness: np.int64(145012)
# ic| best_fitness: np.int64(148137)
# ic| best_fitness: np.int64(149778)
# ic| best_fitness: np.int64(151645)
# ic| best_fitness: np.int64(153099)
# ic| best_fitness: np.int64(156393)
# ic| best_fitness: np.int64(159121)
# ic| best_fitness: np.int64(161764)
# ic| best_fitness: np.int64(163987)
# ic| best_fitness: np.int64(166239)
# ic| best_fitness: np.int64(166979)
# ic| best_fitness: np.int64(168990)
# ic| best_fitness: np.int64(169734)
# ic| best_fitness: np.int64(174097)
# ic| best_fitness: np.int64(176016)
# ic| best_fitness: np.int64(178722)
# ic| best_fitness: np.int64(182504)
# ic| best_fitness: np.int64(186616)
# ic| best_fitness: np.int64(188424)
# ic| best_fitness: np.int64(190953)
# ic| best_fitness: np.int64(193215)
# ic| best_fitness: np.int64(195702)
# ic| best_fitness: np.int64(197146)
# ic| best_fitness: np.int64(199040)
# ic| best_fitness: np.int64(200695)
# ic| best_fitness: np.int64(202087)
# ic| best_fitness: np.int64(204580)
# ic| best_fitness: np.int64(207740)
# ic| best_fitness: np.int64(210331)
# ic| best_fitness: np.int64(212395)
# ic| best_fitness: np.int64(214897)
# ic| best_fitness: np.int64(218317)
# ic| best_fitness: np.int64(219800)
# ic| best_fitness: np.int64(221071)
# ic| best_fitness: np.int64(223894)
# ic| best_fitness: np.int64(227648)
# ic| best_fitness: np.int64(228952)
# ic| best_fitness: np.int64(232363)
# ic| best_fitness: np.int64(234978)
# ic| best_fitness: np.int64(238876)
# ic| best_fitness: np.int64(240426)
# ic| best_fitness: np.int64(242536)
# ic| best_fitness: np.int64(244645)
# ic| best_fitness: np.int64(247585)
# ic| best_fitness: np.int64(249727)
# ic| best_fitness: np.int64(251426)
# ic| best_fitness: np.int64(253305)
# ic| best_fitness: np.int64(254950)
# ic| best_fitness: np.int64(257828)
# ic| best_fitness: np.int64(260132)
# ic| best_fitness: np.int64(261322)
# ic| best_fitness: np.int64(262441)
# ic| best_fitness: np.int64(263570)
# ic| best_fitness: np.int64(263737)
# ic| best_fitness: np.int64(263879)
# ic| best_fitness: np.int64(265353)
# ic| best_fitness: np.int64(266500)
# ic| best_fitness: np.int64(267397)
# ic| best_fitness: np.int64(268645)
# ic| best_fitness: np.int64(270061)
# ic| best_fitness: np.int64(271723)
# ic| best_fitness: np.int64(272719)
# ic| best_fitness: np.int64(273819)
# ic| best_fitness: np.int64(274974)
# ic| best_fitness: np.int64(275254)
# ic| best_fitness: np.int64(278559)
# ic| best_fitness: np.int64(280379)
# ic| best_fitness: np.int64(281687)
# ic| best_fitness: np.int64(283399)
# ic| best_fitness: np.int64(285098)
# ic| best_fitness: np.int64(285676)
# ic| best_fitness: np.int64(286296)
# ic| best_fitness: np.int64(287496)
# ic| best_fitness: np.int64(289860)
# ic| best_fitness: np.int64(290920)
# ic| best_fitness: np.int64(292035)
# ic| best_fitness: np.int64(294501)
# ic| best_fitness: np.int64(296080)
# ic| best_fitness: np.int64(297992)
# ic| best_fitness: np.int64(299012)
# ic| best_fitness: np.int64(299847)
# ic| best_fitness: np.int64(300630)
# ic| best_fitness: np.int64(303352)
# ic| best_fitness: np.int64(305500)
# ic| best_fitness: np.int64(306508)
# ic| best_fitness: np.int64(307660)
# ic| best_fitness: np.int64(309024)
# ic| best_fitness: np.int64(309665)
# ic| best_fitness: np.int64(311186)
# ic| best_fitness: np.int64(312360)
# ic| best_fitness: np.int64(313009)
# ic| best_fitness: np.int64(313962)
# ic| best_fitness: np.int64(315263)
# ic| best_fitness: np.int64(315531)
# ic| best_fitness: np.int64(317326)
# ic| best_fitness: np.int64(318600)
# ic| best_fitness: np.int64(319448)
# ic| best_fitness: np.int64(320307)
# ic| best_fitness: np.int64(320453)
# ic| best_fitness: np.int64(322031)
# ic| best_fitness: np.int64(324574)
# ic| best_fitness: np.int64(325388)
# ic| best_fitness: np.int64(326926)
# ic| best_fitness: np.int64(328053)
# ic| best_fitness: np.int64(329207)
# ic| best_fitness: np.int64(330885)
# ic| best_fitness: np.int64(331695)
# ic| best_fitness: np.int64(332098)
# ic| best_fitness: np.int64(333005)
# ic| best_fitness: np.int64(334234)
# ic| best_fitness: np.int64(334949)
# ic| best_fitness: np.int64(336753)
# ic| best_fitness: np.int64(337177)
# ic| best_fitness: np.int64(337989)
# ic| best_fitness: np.int64(339573)
# ic| best_fitness: np.int64(340024)
# ic| best_fitness: np.int64(342893)
# ic| best_fitness: np.int64(344333)
# ic| best_fitness: np.int64(345422)
# ic| best_fitness: np.int64(346383)
# ic| best_fitness: np.int64(346805)
# ic| best_fitness: np.int64(347740)
# ic| best_fitness: np.int64(350296)
# ic| best_fitness: np.int64(352399)
# ic| best_fitness: np.int64(352801)
# ic| best_fitness: np.int64(354081)
# ic| best_fitness: np.int64(355373)
# ic| best_fitness: np.int64(356349)
# ic| best_fitness: np.int64(357068)
# ic| best_fitness: np.int64(358413)
# ic| best_fitness: np.int64(358783)
# ic| best_fitness: np.int64(358998)
# ic| best_fitness: np.int64(360835)
# ic| best_fitness: np.int64(362599)
# ic| best_fitness: np.int64(365264)
# ic| best_fitness: np.int64(367493)
# ic| best_fitness: np.int64(369604)
# ic| best_fitness: np.int64(371475)
# ic| best_fitness: np.int64(372913)
# ic| best_fitness: np.int64(373642)
# ic| best_fitness: np.int64(374215)
# ic| best_fitness: np.int64(375211)
# ic| best_fitness: np.int64(375739)
# ic| best_fitness: np.int64(376271)
# ic| best_fitness: np.int64(378533)
# ic| best_fitness: np.int64(379420)
# ic| best_fitness: np.int64(379572)
# ic| best_fitness: np.int64(381134)
# ic| best_fitness: np.int64(382105)
# ic| best_fitness: np.int64(383799)
# ic| best_fitness: np.int64(384342)
# ic| best_fitness: np.int64(385353)
# ic| best_fitness: np.int64(385502)
# ic| best_fitness: np.int64(385932)
# ic| best_fitness: np.int64(387232)
# ic| best_fitness: np.int64(389121)
# ic| best_fitness: np.int64(390734)
# ic| best_fitness: np.int64(391294)
# ic| best_fitness: np.int64(391938)
# ic| best_fitness: np.int64(392969)
# ic| best_fitness: np.int64(393997)
# ic| best_fitness: np.int64(394249)
# ic| best_fitness: np.int64(395510)
# ic| best_fitness: np.int64(396828)
# ic| best_fitness: np.int64(398249)
# ic| best_fitness: np.int64(399236)
# ic| best_fitness: np.int64(401617)
# ic| best_fitness: np.int64(402535)
# ic| best_fitness: np.int64(404162)
# ic| best_fitness: np.int64(405298)
# ic| best_fitness: np.int64(405885)
# ic| best_fitness: np.int64(407044)
# ic| best_fitness: np.int64(407834)
# ic| best_fitness: np.int64(408470)
# ic| best_fitness: np.int64(409569)
# ic| best_fitness: np.int64(411818)
# ic| best_fitness: np.int64(413551)
# ic| best_fitness: np.int64(415026)
# ic| best_fitness: np.int64(416573)
# ic| best_fitness: np.int64(417625)
# ic| best_fitness: np.int64(419110)
# ic| best_fitness: np.int64(421498)
# ic| best_fitness: np.int64(423155)
# ic| best_fitness: np.int64(424243)
# ic| best_fitness: np.int64(426117)
# ic| best_fitness: np.int64(427032)
# ic| best_fitness: np.int64(428034)
# ic| best_fitness: np.int64(430014)
# ic| best_fitness: np.int64(430760)
# ic| best_fitness: np.int64(431956)
# ic| best_fitness: np.int64(432643)
# ic| best_fitness: np.int64(433239)
# ic| best_fitness: np.int64(434895)
# ic| best_fitness: np.int64(435165)
# ic| best_fitness: np.int64(437006)
# ic| best_fitness: np.int64(438688)
# ic| best_fitness: np.int64(439096)
# ic| best_fitness: np.int64(439929)
# ic| best_fitness: np.int64(440826)
# ic| best_fitness: np.int64(441218)
# ic| best_fitness: np.int64(442275)
# ic| best_fitness: np.int64(443309)
# ic| best_fitness: np.int64(444143)
# ic| best_fitness: np.int64(445286)
# ic| best_fitness: np.int64(447301)
# ic| best_fitness: np.int64(448108)
# ic| best_fitness: np.int64(450116)
# ic| best_fitness: np.int64(450548)
# ic| best_fitness: np.int64(451221)
# ic| best_fitness: np.int64(452411)
# ic| best_fitness: np.int64(454140)
# ic| best_fitness: np.int64(455536)
# ic| best_fitness: np.int64(456361)
# ic| best_fitness: np.int64(459142)
# ic| best_fitness: np.int64(460681)
# ic| best_fitness: np.int64(461268)
# ic| best_fitness: np.int64(462129)
# ic| best_fitness: np.int64(464235)
# ic| best_fitness: np.int64(465423)
# ic| best_fitness: np.int64(466551)
# ic| best_fitness: np.int64(468277)
# ic| best_fitness: np.int64(468965)
# ic| best_fitness: np.int64(470689)
# ic| best_fitness: np.int64(473183)
# ic| best_fitness: np.int64(475310)
# ic| best_fitness: np.int64(476720)
# ic| best_fitness: np.int64(477532)
# ic| best_fitness: np.int64(478903)
# ic| best_fitness: np.int64(479602)
# ic| best_fitness: np.int64(480604)
# ic| best_fitness: np.int64(480671)
# ic| best_fitness: np.int64(482729)
# ic| best_fitness: np.int64(483697)
# ic| best_fitness: np.int64(484062)
# ic| best_fitness: np.int64(485319)
# ic| best_fitness: np.int64(486697)
# ic| best_fitness: np.int64(488611)
# ic| best_fitness: np.int64(489273)
# ic| best_fitness: np.int64(490790)
# ic| best_fitness: np.int64(492074)
# ic| best_fitness: np.int64(492713)
# ic| best_fitness: np.int64(493029)
# ic| best_fitness: np.int64(495059)
# ic| best_fitness: np.int64(495618)
# ic| best_fitness: np.int64(496528)
# ic| best_fitness: np.int64(497713)
# ic| best_fitness: np.int64(499544)
# ic| best_fitness: np.int64(500854)
# ic| best_fitness: np.int64(502827)
# ic| best_fitness: np.int64(504013)
# ic| best_fitness: np.int64(504417)
# ic| best_fitness: np.int64(505974)
# ic| best_fitness: np.int64(506319)
# ic| best_fitness: np.int64(507147)
# ic| best_fitness: np.int64(508838)
# ic| best_fitness: np.int64(508946)
# ic| best_fitness: np.int64(510414)
# ic| best_fitness: np.int64(511240)
# ic| best_fitness: np.int64(512093)
# ic| best_fitness: np.int64(512616)
# ic| best_fitness: np.int64(513091)
# ic| best_fitness: np.int64(513762)
# ic| best_fitness: np.int64(515380)
# ic| best_fitness: np.int64(516766)
# ic| best_fitness: np.int64(517523)
# ic| best_fitness: np.int64(519060)
# ic| best_fitness: np.int64(520601)
# ic| best_fitness: np.int64(522056)
# ic| best_fitness: np.int64(523567)
# ic| best_fitness: np.int64(525629)
# ic| best_fitness: np.int64(526255)
# ic| best_fitness: np.int64(526635)
# ic| best_fitness: np.int64(527333)
# ic| best_fitness: np.int64(529006)
# ic| best_fitness: np.int64(530326)
# ic| best_fitness: np.int64(533059)
# ic| best_fitness: np.int64(535815)
# ic| best_fitness: np.int64(537988)
# ic| best_fitness: np.int64(538373)
# ic| best_fitness: np.int64(539296)
# ic| best_fitness: np.int64(540502)
# ic| best_fitness: np.int64(541454)
# ic| best_fitness: np.int64(542996)
# ic| best_fitness: np.int64(544158)
# ic| best_fitness: np.int64(544799)
# ic| best_fitness: np.int64(547343)
# ic| best_fitness: np.int64(548876)
# ic| best_fitness: np.int64(549434)
# ic| best_fitness: np.int64(550456)
# ic| best_fitness: np.int64(552280)
# ic| best_fitness: np.int64(552658)
# ic| best_fitness: np.int64(555183)
# ic| best_fitness: np.int64(557239)
# ic| best_fitness: np.int64(558555)
# ic| best_fitness: np.int64(559516)
# ic| best_fitness: np.int64(561707)
# ic| best_fitness: np.int64(563641)
# ic| best_fitness: np.int64(565506)
# ic| best_fitness: np.int64(566193)
# ic| best_fitness: np.int64(567545)
# ic| best_fitness: np.int64(569071)
# ic| best_fitness: np.int64(569915)
# ic| best_fitness: np.int64(570597)
# ic| best_fitness: np.int64(571234)
# ic| best_fitness: np.int64(572995)
# ic| best_fitness: np.int64(573318)
# ic| best_fitness: np.int64(575379)
# ic| best_fitness: np.int64(576595)
# ic| best_fitness: np.int64(577921)
# ic| best_fitness: np.int64(579498)
# ic| best_fitness: np.int64(581649)
# ic| best_fitness: np.int64(583298)
# ic| best_fitness: np.int64(585306)
# ic| best_fitness: np.int64(587044)
# ic| best_fitness: np.int64(587531)
# ic| best_fitness: np.int64(588933)
# ic| best_fitness: np.int64(590220)
# ic| best_fitness: np.int64(591836)
# ic| best_fitness: np.int64(594011)
# ic| best_fitness: np.int64(595009)
# ic| best_fitness: np.int64(595010)
# ic| best_fitness: np.int64(595753)
# ic| best_fitness: np.int64(596654)
# ic| best_fitness: np.int64(597590)
# ic| best_fitness: np.int64(600224)
# ic| best_fitness: np.int64(600978)
# ic| best_fitness: np.int64(601704)
# ic| best_fitness: np.int64(602263)
# ic| best_fitness: np.int64(603584)
# ic| best_fitness: np.int64(603870)
# ic| best_fitness: np.int64(603891)
# ic| best_fitness: np.int64(604581)
# ic| best_fitness: np.int64(605437)
# ic| best_fitness: np.int64(606932)
# ic| best_fitness: np.int64(607586)
# ic| best_fitness: np.int64(609776)
# ic| best_fitness: np.int64(611454)
# ic| best_fitness: np.int64(613068)
# ic| best_fitness: np.int64(614225)
# ic| best_fitness: np.int64(616087)
# ic| best_fitness: np.int64(617573)
# ic| best_fitness: np.int64(618478)
# ic| best_fitness: np.int64(620166)
# ic| best_fitness: np.int64(621292)
# ic| best_fitness: np.int64(622768)
# ic| best_fitness: np.int64(624871)
# ic| best_fitness: np.int64(625691)
# ic| best_fitness: np.int64(627098)
# ic| best_fitness: np.int64(627937)
# ic| best_fitness: np.int64(628871)
# ic| best_fitness: np.int64(629367)
# ic| best_fitness: np.int64(629834)
# ic| best_fitness: np.int64(631677)
# ic| best_fitness: np.int64(632557)
# ic| best_fitness: np.int64(635079)
# ic| best_fitness: np.int64(636065)
# ic| best_fitness: np.int64(638702)
# ic| best_fitness: np.int64(640361)
# ic| best_fitness: np.int64(641713)
# ic| best_fitness: np.int64(642209)
# ic| best_fitness: np.int64(642825)
# ic| best_fitness: np.int64(643738)
# ic| best_fitness: np.int64(644737)
# ic| best_fitness: np.int64(645311)
# ic| best_fitness: np.int64(646229)
# ic| best_fitness: np.int64(646791)
# ic| best_fitness: np.int64(646953)
# ic| best_fitness: np.int64(647449)
# ic| best_fitness: np.int64(648481)
# ic| best_fitness: np.int64(649519)
# ic| best_fitness: np.int64(650397)
# ic| best_fitness: np.int64(651730)
# ic| best_fitness: np.int64(653515)
# ic| best_fitness: np.int64(656379)
# ic| best_fitness: np.int64(657199)
# ic| best_fitness: np.int64(657640)
# ic| best_fitness: np.int64(658334)
# ic| best_fitness: np.int64(659379)
# ic| best_fitness: np.int64(660622)
# ic| best_fitness: np.int64(661545)
# ic| best_fitness: np.int64(661902)
# ic| best_fitness: np.int64(664430)
# ic| best_fitness: np.int64(665352)
# ic| best_fitness: np.int64(665934)
# ic| best_fitness: np.int64(667168)
# ic| best_fitness: np.int64(668124)
# ic| best_fitness: np.int64(669147)
# ic| best_fitness: np.int64(671295)
# ic| best_fitness: np.int64(673384)
# ic| best_fitness: np.int64(674355)
# ic| best_fitness: np.int64(675177)
# ic| best_fitness: np.int64(676832)
# ic| best_fitness: np.int64(677930)
# ic| best_fitness: np.int64(679790)
# ic| best_fitness: np.int64(680766)
# ic| best_fitness: np.int64(682197)
# ic| best_fitness: np.int64(683166)
# ic| best_fitness: np.int64(684816)
# ic| best_fitness: np.int64(685523)
# ic| best_fitness: np.int64(686222)
# ic| best_fitness: np.int64(687269)
# ic| best_fitness: np.int64(688198)
# ic| best_fitness: np.int64(688341)
# ic| best_fitness: np.int64(690339)
# ic| best_fitness: np.int64(691990)
# ic| best_fitness: np.int64(692747)
# ic| best_fitness: np.int64(694787)
# ic| best_fitness: np.int64(695599)
# ic| best_fitness: np.int64(696272)
# ic| best_fitness: np.int64(697082)
# ic| best_fitness: np.int64(699129)
# ic| best_fitness: np.int64(700495)
# ic| best_fitness: np.int64(702007)
# ic| best_fitness: np.int64(703525)
# ic| best_fitness: np.int64(703643)
# ic| best_fitness: np.int64(704143)
# ic| best_fitness: np.int64(705633)
# ic| best_fitness: np.int64(706125)
# ic| best_fitness: np.int64(706874)
# ic| best_fitness: np.int64(707385)
# ic| best_fitness: np.int64(708587)
# ic| best_fitness: np.int64(709161)
# ic| best_fitness: np.int64(709262)
# ic| best_fitness: np.int64(710119)
# ic| best_fitness: np.int64(711449)
# ic| best_fitness: np.int64(712258)
# ic| best_fitness: np.int64(714085)
# ic| best_fitness: np.int64(715829)
# ic| best_fitness: np.int64(716106)
# ic| best_fitness: np.int64(718503)
# ic| best_fitness: np.int64(719833)
# ic| best_fitness: np.int64(721211)
# ic| best_fitness: np.int64(723202)
# ic| best_fitness: np.int64(723648)
# ic| best_fitness: np.int64(723882)
# ic| best_fitness: np.int64(724487)
# ic| best_fitness: np.int64(725094)
# ic| best_fitness: np.int64(725147)
# ic| best_fitness: np.int64(725910)
# ic| best_fitness: np.int64(726367)
# ic| best_fitness: np.int64(726603)
# ic| best_fitness: np.int64(726876)
# ic| best_fitness: np.int64(727585)
# ic| best_fitness: np.int64(728055)
# ic| best_fitness: np.int64(728329)
# ic| best_fitness: np.int64(729566)
# ic| best_fitness: np.int64(731078)
# ic| best_fitness: np.int64(731503)
# ic| best_fitness: np.int64(732335)
# ic| best_fitness: np.int64(733299)
# ic| best_fitness: np.int64(734950)
# ic| best_fitness: np.int64(735166)
# ic| best_fitness: np.int64(735857)
# ic| best_fitness: np.int64(736132)
# ic| best_fitness: np.int64(736949)
# ic| best_fitness: np.int64(738549)
# ic| best_fitness: np.int64(738877)
# ic| best_fitness: np.int64(740059)
# ic| best_fitness: np.int64(741483)
# ic| best_fitness: np.int64(742848)
# ic| best_fitness: np.int64(743912)
# ic| best_fitness: np.int64(745114)
# ic| best_fitness: np.int64(747252)
# ic| best_fitness: np.int64(748201)
# ic| best_fitness: np.int64(749838)
# ic| best_fitness: np.int64(750903)
# ic| best_fitness: np.int64(751492)
# ic| best_fitness: np.int64(754554)
# ic| best_fitness: np.int64(756797)
# ic| best_fitness: np.int64(757219)
# ic| best_fitness: np.int64(757800)
# ic| best_fitness: np.int64(759342)
# ic| best_fitness: np.int64(759648)
# ic| best_fitness: np.int64(761265)
# ic| best_fitness: np.int64(761569)
# ic| best_fitness: np.int64(762376)
# ic| best_fitness: np.int64(762936)
# ic| best_fitness: np.int64(763467)
# ic| best_fitness: np.int64(764047)
# ic| best_fitness: np.int64(765041)
# ic| best_fitness: np.int64(765646)
# ic| best_fitness: np.int64(766279)
# ic| best_fitness: np.int64(766695)
# ic| best_fitness: np.int64(767513)
# ic| best_fitness: np.int64(768292)
# ic| best_fitness: np.int64(768897)
# ic| best_fitness: np.int64(769554)
# ic| best_fitness: np.int64(769932)
# ic| best_fitness: np.int64(770701)
# ic| best_fitness: np.int64(771549)
# ic| best_fitness: np.int64(772461)
# ic| best_fitness: np.int64(773919)
# ic| best_fitness: np.int64(774793)
# ic| best_fitness: np.int64(775423)
# ic| best_fitness: np.int64(776586)
# ic| best_fitness: np.int64(777517)
# ic| best_fitness: np.int64(777672)
# ic| best_fitness: np.int64(778269)
# ic| best_fitness: np.int64(779108)
# ic| best_fitness: np.int64(779905)
# ic| best_fitness: np.int64(780692)
# ic| best_fitness: np.int64(781025)
# ic| best_fitness: np.int64(781168)
# ic| best_fitness: np.int64(782133)
# ic| best_fitness: np.int64(782807)
# ic| best_fitness: np.int64(783557)
# ic| best_fitness: np.int64(783746)
# ic| best_fitness: np.int64(784058)
# ic| best_fitness: np.int64(785354)
# ic| best_fitness: np.int64(785847)
# ic| best_fitness: np.int64(786631)
# ic| best_fitness: np.int64(786862)
# ic| best_fitness: np.int64(787687)
# ic| best_fitness: np.int64(788105)
# ic| best_fitness: np.int64(788721)
# ic| best_fitness: np.int64(788874)
# ic| best_fitness: np.int64(788886)
# ic| best_fitness: np.int64(789815)
# ic| best_fitness: np.int64(790572)
# ic| best_fitness: np.int64(791434)
# ic| best_fitness: np.int64(791564)
# ic| best_fitness: np.int64(792155)
# ic| best_fitness: np.int64(792256)
# ic| best_fitness: np.int64(792674)
# ic| best_fitness: np.int64(793591)
# ic| best_fitness: np.int64(793941)
# ic| best_fitness: np.int64(794466)
# ic| best_fitness: np.int64(794735)
# ic| best_fitness: np.int64(794921)
# ic| best_fitness: np.int64(795245)
# ic| best_fitness: np.int64(795460)
# ic| best_fitness: np.int64(795790)
# ic| best_fitness: np.int64(796495)
# ic| best_fitness: np.int64(797448)
# ic| best_fitness: np.int64(797861)
# ic| best_fitness: np.int64(799203)
# ic| best_fitness: np.int64(799998)
# ic| best_fitness: np.int64(800848)
# ic| best_fitness: np.int64(801083)
# ic| best_fitness: np.int64(801825)
# ic| best_fitness: np.int64(801916)
# ic| best_fitness: np.int64(803713)
# ic| best_fitness: np.int64(804540)
# ic| best_fitness: np.int64(805104)
# ic| best_fitness: np.int64(805306)
# ic| best_fitness: np.int64(806049)
# ic| best_fitness: np.int64(806359)
# ic| best_fitness: np.int64(807268)
# ic| best_fitness: np.int64(807684)
# ic| best_fitness: np.int64(808624)
# ic| best_fitness: np.int64(808777)
# ic| best_fitness: np.int64(809519)
# ic| best_fitness: np.int64(810485)
# ic| best_fitness: np.int64(810824)
# ic| best_fitness: np.int64(811357)
# ic| best_fitness: np.int64(812031)
# ic| best_fitness: np.int64(812222)
# ic| best_fitness: np.int64(812335)
# ic| best_fitness: np.int64(813308)
# ic| best_fitness: np.int64(813941)
# ic| best_fitness: np.int64(815001)
# ic| best_fitness: np.int64(815126)
# ic| best_fitness: np.int64(815206)
# ic| best_fitness: np.int64(815837)
# ic| best_fitness: np.int64(816135)
# ic| best_fitness: np.int64(817946)
# ic| best_fitness: np.int64(818260)
# ic| best_fitness: np.int64(818315)
# ic| best_fitness: np.int64(819474)
# ic| best_fitness: np.int64(820106)
# ic| best_fitness: np.int64(820489)
# ic| best_fitness: np.int64(821188)
# ic| best_fitness: np.int64(821365)
# ic| best_fitness: np.int64(821611)
# ic| best_fitness: np.int64(822319)
# ic| best_fitness: np.int64(822665)
# ic| best_fitness: np.int64(823800)
# ic| best_fitness: np.int64(824490)
# ic| best_fitness: np.int64(824903)
# ic| best_fitness: np.int64(825730)
# ic| best_fitness: np.int64(826576)
# ic| best_fitness: np.int64(826830)
# ic| best_fitness: np.int64(827446)
# ic| best_fitness: np.int64(827480)
# ic| best_fitness: np.int64(828816)
# ic| best_fitness: np.int64(829593)
# ic| best_fitness: np.int64(829760)
# ic| best_fitness: np.int64(831061)
# ic| best_fitness: np.int64(831912)
# ic| best_fitness: np.int64(832208)
# ic| best_fitness: np.int64(833061)
# ic| best_fitness: np.int64(833671)
# ic| best_fitness: np.int64(834665)
# ic| best_fitness: np.int64(835133)
# ic| best_fitness: np.int64(835956)
# ic| best_fitness: np.int64(836462)
# ic| best_fitness: np.int64(837711)
# ic| best_fitness: np.int64(838363)
# ic| best_fitness: np.int64(839077)
# ic| best_fitness: np.int64(839623)
# ic| best_fitness: np.int64(840392)
# ic| best_fitness: np.int64(840607)
# ic| best_fitness: np.int64(841464)
# ic| best_fitness: np.int64(842324)
# ic| best_fitness: np.int64(842858)
# ic| best_fitness: np.int64(843557)
# ic| best_fitness: np.int64(844383)
# ic| best_fitness: np.int64(845151)
# ic| best_fitness: np.int64(845757)
# ic| best_fitness: np.int64(846142)
# ic| best_fitness: np.int64(846203)
# ic| best_fitness: np.int64(846920)
# ic| best_fitness: np.int64(847949)
# ic| best_fitness: np.int64(848464)
# ic| best_fitness: np.int64(848968)
# ic| best_fitness: np.int64(849545)
# ic| best_fitness: np.int64(849812)
# ic| best_fitness: np.int64(851198)
# ic| best_fitness: np.int64(851303)
# ic| best_fitness: np.int64(852222)
# ic| best_fitness: np.int64(852479)
# ic| best_fitness: np.int64(853411)
# ic| best_fitness: np.int64(855036)
# ic| best_fitness: np.int64(855176)
# ic| best_fitness: np.int64(855802)
# ic| best_fitness: np.int64(855935)
# ic| best_fitness: np.int64(855972)
# ic| best_fitness: np.int64(856056)
# ic| best_fitness: np.int64(857485)
# ic| best_fitness: np.int64(857681)
# ic| best_fitness: np.int64(858049)
# ic| best_fitness: np.int64(858354)
# ic| best_fitness: np.int64(858801)
# ic| best_fitness: np.int64(859471)
# ic| best_fitness: np.int64(859598)
# ic| best_fitness: np.int64(860065)
# ic| best_fitness: np.int64(860583)
# ic| best_fitness: np.int64(860650)
# ic| best_fitness: np.int64(861029)
# ic| best_fitness: np.int64(861552)
# ic| best_fitness: np.int64(862120)
# ic| best_fitness: np.int64(862404)
# ic| best_fitness: np.int64(862700)
# ic| best_fitness: np.int64(863530)
# ic| best_fitness: np.int64(864370)
# ic| best_fitness: np.int64(865616)
# ic| best_fitness: np.int64(865874)
# ic| best_fitness: np.int64(866128)
# ic| best_fitness: np.int64(866427)
# ic| best_fitness: np.int64(866667)
# ic| best_fitness: np.int64(867301)
# ic| best_fitness: np.int64(868122)
# ic| best_fitness: np.int64(868914)
# ic| best_fitness: np.int64(870506)
# ic| best_fitness: np.int64(870939)
# ic| best_fitness: np.int64(872124)
# ic| best_fitness: np.int64(873020)
# ic| best_fitness: np.int64(873558)
# ic| best_fitness: np.int64(874504)
# ic| best_fitness: np.int64(874539)
# ic| best_fitness: np.int64(875458)
# ic| best_fitness: np.int64(875837)
# ic| best_fitness: np.int64(876674)
# ic| best_fitness: np.int64(877432)
# ic| best_fitness: np.int64(877545)
# ic| best_fitness: np.int64(878726)
# ic| best_fitness: np.int64(879128)
# ic| best_fitness: np.int64(879486)
# ic| best_fitness: np.int64(880260)
# ic| best_fitness: np.int64(880981)
# ic| best_fitness: np.int64(882022)
# ic| best_fitness: np.int64(882919)
# ic| best_fitness: np.int64(883943)
# ic| best_fitness: np.int64(884077)
# ic| best_fitness: np.int64(884760)
# ic| best_fitness: np.int64(885271)
# ic| best_fitness: np.int64(886368)
# ic| best_fitness: np.int64(887581)
# ic| best_fitness: np.int64(887940)
# ic| best_fitness: np.int64(888267)
# ic| best_fitness: np.int64(889318)
# ic| best_fitness: np.int64(890159)
# ic| best_fitness: np.int64(890664)
# ic| best_fitness: np.int64(890959)
# ic| best_fitness: np.int64(891617)
# ic| best_fitness: np.int64(891716)
# ic| best_fitness: np.int64(892705)
# ic| best_fitness: np.int64(893324)
# ic| best_fitness: np.int64(894081)
# ic| best_fitness: np.int64(894952)
# ic| best_fitness: np.int64(895065)
# ic| best_fitness: np.int64(895528)
# ic| best_fitness: np.int64(895777)
# ic| best_fitness: np.int64(895865)
# ic| best_fitness: np.int64(896586)
# ic| best_fitness: np.int64(897190)
# ic| best_fitness: np.int64(898022)
# ic| best_fitness: np.int64(898935)
# ic| best_fitness: np.int64(899759)
# ic| best_fitness: np.int64(900669)
# ic| best_fitness: np.int64(901352)
# ic| best_fitness: np.int64(902315)
# ic| best_fitness: np.int64(903224)
# ic| best_fitness: np.int64(903579)
# ic| best_fitness: np.int64(904075)
# ic| best_fitness: np.int64(905358)
# ic| best_fitness: np.int64(905454)
# ic| best_fitness: np.int64(905755)
# ic| best_fitness: np.int64(906614)
# ic| best_fitness: np.int64(906681)
# ic| best_fitness: np.int64(907705)
# ic| best_fitness: np.int64(908685)
# ic| best_fitness: np.int64(909114)
# ic| best_fitness: np.int64(909601)
# ic| best_fitness: np.int64(910450)
# ic| best_fitness: np.int64(910642)
# ic| best_fitness: np.int64(911376)
# ic| best_fitness: np.int64(911738)
# ic| best_fitness: np.int64(911844)
# ic| best_fitness: np.int64(912582)
# ic| best_fitness: np.int64(912923)
# ic| best_fitness: np.int64(913064)
# ic| best_fitness: np.int64(913202)
# ic| best_fitness: np.int64(913879)
# ic| best_fitness: np.int64(914023)
# ic| best_fitness: np.int64(914091)
# ic| best_fitness: np.int64(914693)
# ic| best_fitness: np.int64(915690)
# ic| best_fitness: np.int64(916566)
# ic| best_fitness: np.int64(916983)
# ic| best_fitness: np.int64(917464)
# ic| best_fitness: np.int64(917753)
# ic| best_fitness: np.int64(917774)
# ic| best_fitness: np.int64(917985)
# ic| best_fitness: np.int64(918516)
# ic| best_fitness: np.int64(918878)
# ic| best_fitness: np.int64(919143)
# ic| best_fitness: np.int64(919144)
# ic| best_fitness: np.int64(919712)
# ic| best_fitness: np.int64(920426)
# ic| best_fitness: np.int64(920661)
# ic| best_fitness: np.int64(921462)
# ic| best_fitness: np.int64(921528)
# ic| best_fitness: np.int64(922232)
# ic| best_fitness: np.int64(923150)
# ic| best_fitness: np.int64(923616)
# ic| best_fitness: np.int64(925059)
# ic| best_fitness: np.int64(925212)
# ic| best_fitness: np.int64(925252)
# ic| best_fitness: np.int64(926583)
# ic| best_fitness: np.int64(927036)
# ic| best_fitness: np.int64(927318)
# ic| best_fitness: np.int64(927321)
# ic| best_fitness: np.int64(927698)
# ic| best_fitness: np.int64(928172)
# ic| best_fitness: np.int64(928287)
# ic| best_fitness: np.int64(928650)
# ic| best_fitness: np.int64(928981)
# ic| best_fitness: np.int64(929662)
# ic| best_fitness: np.int64(930569)
# ic| best_fitness: np.int64(932360)
# ic| best_fitness: np.int64(933252)
# ic| best_fitness: np.int64(933577)
# ic| best_fitness: np.int64(934560)
# ic| best_fitness: np.int64(934792)
# ic| best_fitness: np.int64(935379)
# ic| best_fitness: np.int64(935639)
# ic| best_fitness: np.int64(936345)
# ic| best_fitness: np.int64(936800)
# ic| best_fitness: np.int64(937272)
# ic| best_fitness: np.int64(937678)
# ic| best_fitness: np.int64(938040)
# ic| best_fitness: np.int64(938341)
# ic| best_fitness: np.int64(939005)
# ic| best_fitness: np.int64(939704)
# ic| best_fitness: np.int64(940048)
# ic| best_fitness: np.int64(940645)
# ic| best_fitness: np.int64(940750)
# ic| best_fitness: np.int64(941370)
# ic| best_fitness: np.int64(941509)
# ic| best_fitness: np.int64(942042)
# ic| best_fitness: np.int64(942220)
# ic| best_fitness: np.int64(943045)
# ic| best_fitness: np.int64(943794)
# ic| best_fitness: np.int64(944772)
# ic| best_fitness: np.int64(945276)
# ic| best_fitness: np.int64(946254)
# ic| best_fitness: np.int64(946878)
# ic| best_fitness: np.int64(948062)
# ic| best_fitness: np.int64(948650)
# ic| best_fitness: np.int64(949010)
# ic| best_fitness: np.int64(950000)
# ic| best_fitness: np.int64(950103)
# ic| best_fitness: np.int64(951238)
# ic| best_fitness: np.int64(951792)
# ic| best_fitness: np.int64(952518)
# ic| best_fitness: np.int64(953456)
# ic| best_fitness: np.int64(953680)
# ic| best_fitness: np.int64(954517)
# ic| best_fitness: np.int64(955365)
# ic| best_fitness: np.int64(956000)
# ic| best_fitness: np.int64(956874)
# ic| best_fitness: np.int64(957092)
# ic| best_fitness: np.int64(957606)
# ic| best_fitness: np.int64(958485)
# ic| best_fitness: np.int64(958921)
# ic| best_fitness: np.int64(959285)
# ic| best_fitness: np.int64(959440)
# ic| best_fitness: np.int64(959896)
# ic| best_fitness: np.int64(960483)
# ic| best_fitness: np.int64(961247)
# ic| best_fitness: np.int64(962022)
# ic| best_fitness: np.int64(962891)
# ic| best_fitness: np.int64(963192)
# ic| best_fitness: np.int64(963634)
# ic| best_fitness: np.int64(964235)
# ic| best_fitness: np.int64(964765)
# ic| best_fitness: np.int64(964769)
# ic| best_fitness: np.int64(964810)
# ic| best_fitness: np.int64(965515)
# ic| best_fitness: np.int64(965605)
# ic| best_fitness: np.int64(966020)
# ic| best_fitness: np.int64(966724)
# ic| best_fitness: np.int64(967107)
# ic| best_fitness: np.int64(967584)
# ic| best_fitness: np.int64(967969)
# ic| best_fitness: np.int64(968496)
# ic| best_fitness: np.int64(968741)
# ic| best_fitness: np.int64(969029)
# ic| best_fitness: np.int64(969470)
# ic| best_fitness: np.int64(970044)
# ic| best_fitness: np.int64(970411)
# ic| best_fitness: np.int64(970621)
# ic| best_fitness: np.int64(971011)
# ic| best_fitness: np.int64(971558)
# ic| best_fitness: np.int64(972016)
# ic| best_fitness: np.int64(972088)
# ic| best_fitness: np.int64(973591)
# ic| best_fitness: np.int64(974542)
# ic| best_fitness: np.int64(975710)
# ic| best_fitness: np.int64(977484)
# ic| best_fitness: np.int64(978262)
# ic| best_fitness: np.int64(979096)
# ic| best_fitness: np.int64(979564)
# ic| best_fitness: np.int64(979883)
# ic| best_fitness: np.int64(980752)
# ic| best_fitness: np.int64(981086)
# ic| best_fitness: np.int64(981135)
# ic| best_fitness: np.int64(981631)
# ic| best_fitness: np.int64(982209)
# ic| best_fitness: np.int64(983171)
# ic| best_fitness: np.int64(984021)
# ic| best_fitness: np.int64(984601)
# ic| best_fitness: np.int64(984655)
# ic| best_fitness: np.int64(985406)
# ic| best_fitness: np.int64(986329)
# ic| best_fitness: np.int64(986514)
# ic| best_fitness: np.int64(987366)
# ic| best_fitness: np.int64(988282)
# ic| best_fitness: np.int64(989042)
# ic| best_fitness: np.int64(989243)
# ic| best_fitness: np.int64(990080)
# ic| best_fitness: np.int64(990955)
# ic| best_fitness: np.int64(991726)
# ic| best_fitness: np.int64(991928)
# ic| best_fitness: np.int64(992569)
# ic| best_fitness: np.int64(992946)
# ic| best_fitness: np.int64(994645)
# ic| best_fitness: np.int64(995304)
# ic| best_fitness: np.int64(995742)
# ic| best_fitness: np.int64(996548)
# ic| best_fitness: np.int64(997325)
# ic| best_fitness: np.int64(997766)
# ic| best_fitness: np.int64(998381)
# ic| best_fitness: np.int64(998915)
# ic| best_fitness: np.int64(999648)
# ic| best_fitness: np.int64(1000468)
# ic| best_fitness: np.int64(1000781)
# ic| best_fitness: np.int64(1001202)
# ic| best_fitness: np.int64(1001796)
# ic| best_fitness: np.int64(1001956)
# ic| best_fitness: np.int64(1002293)
# ic| best_fitness: np.int64(1002396)
# ic| best_fitness: np.int64(1002957)
# ic| best_fitness: np.int64(1003142)
# ic| best_fitness: np.int64(1003969)
# ic| best_fitness: np.int64(1004724)
# ic| best_fitness: np.int64(1006040)
# ic| best_fitness: np.int64(1006976)
# ic| best_fitness: np.int64(1007968)
# ic| best_fitness: np.int64(1007986)
# ic| best_fitness: np.int64(1008498)
# ic| best_fitness: np.int64(1008763)
# ic| best_fitness: np.int64(1009803)
# ic| best_fitness: np.int64(1010653)
# ic| best_fitness: np.int64(1011301)
# ic| best_fitness: np.int64(1011995)
# ic| best_fitness: np.int64(1012793)
# ic| best_fitness: np.int64(1013643)
# ic| best_fitness: np.int64(1013985)
# ic| best_fitness: np.int64(1014178)
# ic| best_fitness: np.int64(1014796)
# ic| best_fitness: np.int64(1014895)
# ic| best_fitness: np.int64(1015065)
# ic| best_fitness: np.int64(1015146)
# ic| best_fitness: np.int64(1015786)
# ic| best_fitness: np.int64(1016037)
# ic| best_fitness: np.int64(1016313)
# ic| best_fitness: np.int64(1018069)
# ic| best_fitness: np.int64(1019007)
# ic| best_fitness: np.int64(1019113)
# ic| best_fitness: np.int64(1019499)
# ic| best_fitness: np.int64(1019900)
# ic| best_fitness: np.int64(1020453)
# ic| best_fitness: np.int64(1021156)
# ic| best_fitness: np.int64(1021216)
# ic| best_fitness: np.int64(1021218)
# ic| best_fitness: np.int64(1022009)
# ic| best_fitness: np.int64(1022163)
# ic| best_fitness: np.int64(1022902)
# ic| best_fitness: np.int64(1023861)
# ic| best_fitness: np.int64(1023897)
# ic| best_fitness: np.int64(1024099)
# ic| best_fitness: np.int64(1024922)
# ic| best_fitness: np.int64(1025897)
# ic| best_fitness: np.int64(1026177)
# ic| best_fitness: np.int64(1026957)
# ic| best_fitness: np.int64(1027284)
# ic| best_fitness: np.int64(1028199)
# ic| best_fitness: np.int64(1028363)
# ic| best_fitness: np.int64(1028741)
# ic| best_fitness: np.int64(1029418)
# ic| best_fitness: np.int64(1029859)
# ic| best_fitness: np.int64(1030794)
# ic| best_fitness: np.int64(1031242)
# ic| best_fitness: np.int64(1031493)
# ic| best_fitness: np.int64(1031552)
# ic| best_fitness: np.int64(1032452)
# ic| best_fitness: np.int64(1032958)
# ic| best_fitness: np.int64(1034145)
# ic| best_fitness: np.int64(1034219)
# ic| best_fitness: np.int64(1035108)
# ic| best_fitness: np.int64(1035380)
# ic| best_fitness: np.int64(1035625)
# ic| best_fitness: np.int64(1036061)
# ic| best_fitness: np.int64(1036653)
# ic| best_fitness: np.int64(1036679)
# ic| best_fitness: np.int64(1036728)
# ic| best_fitness: np.int64(1037251)
# ic| best_fitness: np.int64(1037694)
# ic| best_fitness: np.int64(1038625)
# ic| best_fitness: np.int64(1039047)
# ic| best_fitness: np.int64(1039106)
# ic| best_fitness: np.int64(1039613)
# ic| best_fitness: np.int64(1040212)
# ic| best_fitness: np.int64(1040315)
# ic| best_fitness: np.int64(1041262)
# ic| best_fitness: np.int64(1041699)
# ic| best_fitness: np.int64(1041716)
# ic| best_fitness: np.int64(1042432)
# ic| best_fitness: np.int64(1042607)
# ic| best_fitness: np.int64(1042629)
# ic| best_fitness: np.int64(1043470)
# ic| best_fitness: np.int64(1044454)
# ic| best_fitness: np.int64(1045115)
# ic| best_fitness: np.int64(1045630)
# ic| best_fitness: np.int64(1045873)
# ic| best_fitness: np.int64(1046718)
# ic| best_fitness: np.int64(1046927)
# ic| best_fitness: np.int64(1047717)
# ic| best_fitness: np.int64(1048559)
# ic| best_fitness: np.int64(1049112)
# ic| best_fitness: np.int64(1050057)
# ic| best_fitness: np.int64(1050478)
# ic| best_fitness: np.int64(1051055)
# ic| best_fitness: np.int64(1051582)
# ic| best_fitness: np.int64(1052454)
# ic| best_fitness: np.int64(1053064)
# ic| best_fitness: np.int64(1054704)
# ic| best_fitness: np.int64(1055297)
# ic| best_fitness: np.int64(1056825)
# ic| best_fitness: np.int64(1057116)
# ic| best_fitness: np.int64(1057456)
# ic| best_fitness: np.int64(1057585)
# ic| best_fitness: np.int64(1057843)
# ic| best_fitness: np.int64(1057998)
# ic| best_fitness: np.int64(1058746)
# ic| best_fitness: np.int64(1059158)
# ic| best_fitness: np.int64(1059848)
# ic| best_fitness: np.int64(1060328)
# ic| best_fitness: np.int64(1060790)
# ic| best_fitness: np.int64(1062273)
# ic| best_fitness: np.int64(1062317)
# ic| best_fitness: np.int64(1062471)
# ic| best_fitness: np.int64(1062543)
# ic| best_fitness: np.int64(1063478)
# ic| best_fitness: np.int64(1063585)
# ic| best_fitness: np.int64(1064356)
# ic| best_fitness: np.int64(1064699)
# ic| best_fitness: np.int64(1064845)
# ic| best_fitness: np.int64(1066186)
# ic| best_fitness: np.int64(1066226)
# ic| best_fitness: np.int64(1066543)
# ic| best_fitness: np.int64(1066669)
# ic| best_fitness: np.int64(1067043)
# ic| best_fitness: np.int64(1067793)
# ic| best_fitness: np.int64(1068075)
# ic| best_fitness: np.int64(1068345)
# ic| best_fitness: np.int64(1069119)
# ic| best_fitness: np.int64(1069454)
# ic| best_fitness: np.int64(1069887)
# ic| best_fitness: np.int64(1070017)
# ic| best_fitness: np.int64(1070805)
# ic| best_fitness: np.int64(1070863)
# ic| best_fitness: np.int64(1071613)
# ic| best_fitness: np.int64(1071693)
# ic| best_fitness: np.int64(1072163)
# ic| best_fitness: np.int64(1072426)
# ic| best_fitness: np.int64(1073344)
# ic| best_fitness: np.int64(1073856)
# ic| best_fitness: np.int64(1074176)
# ic| best_fitness: np.int64(1074691)
# ic| best_fitness: np.int64(1075246)
# ic| best_fitness: np.int64(1075277)
# ic| best_fitness: np.int64(1075496)
# ic| best_fitness: np.int64(1076110)
# ic| best_fitness: np.int64(1076493)
# ic| best_fitness: np.int64(1077356)
# ic| best_fitness: np.int64(1078355)
# ic| best_fitness: np.int64(1079295)
# ic| best_fitness: np.int64(1080141)
# ic| best_fitness: np.int64(1080156)
# ic| best_fitness: np.int64(1081133)
# ic| best_fitness: np.int64(1081485)
# ic| best_fitness: np.int64(1081758)
# ic| best_fitness: np.int64(1082173)
# ic| best_fitness: np.int64(1082559)
# ic| best_fitness: np.int64(1083966)
# ic| best_fitness: np.int64(1084939)
# ic| best_fitness: np.int64(1085192)
# ic| best_fitness: np.int64(1085909)
# ic| best_fitness: np.int64(1086899)
# ic| best_fitness: np.int64(1087026)
# ic| best_fitness: np.int64(1087652)
# ic| best_fitness: np.int64(1088069)
# ic| best_fitness: np.int64(1088941)
# ic| best_fitness: np.int64(1089284)
# ic| best_fitness: np.int64(1089591)
# ic| best_fitness: np.int64(1090534)
# ic| best_fitness: np.int64(1090816)
# ic| best_fitness: np.int64(1090936)
# ic| best_fitness: np.int64(1091410)
# ic| best_fitness: np.int64(1092243)
# ic| best_fitness: np.int64(1092478)
# ic| best_fitness: np.int64(1092567)
# ic| best_fitness: np.int64(1092723)
# ic| best_fitness: np.int64(1093509)
# ic| best_fitness: np.int64(1093515)
# ic| best_fitness: np.int64(1093950)
# ic| best_fitness: np.int64(1094488)
# ic| best_fitness: np.int64(1095768)
# ic| best_fitness: np.int64(1095772)
# ic| best_fitness: np.int64(1096521)
# ic| best_fitness: np.int64(1097043)
# ic| best_fitness: np.int64(1097829)
# ic| best_fitness: np.int64(1098584)
# ic| best_fitness: np.int64(1099358)
# ic| best_fitness: np.int64(1099972)
# ic| best_fitness: np.int64(1100019)
# ic| best_fitness: np.int64(1100406)
# ic| best_fitness: np.int64(1100571)
# ic| best_fitness: np.int64(1101531)
# ic| best_fitness: np.int64(1102380)
# ic| best_fitness: np.int64(1102565)
# ic| best_fitness: np.int64(1102711)
# ic| best_fitness: np.int64(1103507)
# ic| best_fitness: np.int64(1103953)
# ic| best_fitness: np.int64(1104942)
# ic| best_fitness: np.int64(1105190)
# ic| best_fitness: np.int64(1105697)
# ic| best_fitness: np.int64(1106620)
# ic| best_fitness: np.int64(1107510)
# ic| best_fitness: np.int64(1107955)
# ic| best_fitness: np.int64(1108015)
# ic| best_fitness: np.int64(1108131)
# ic| best_fitness: np.int64(1109294)
# ic| best_fitness: np.int64(1109824)
# ic| best_fitness: np.int64(1110121)
# ic| best_fitness: np.int64(1110468)
# ic| best_fitness: np.int64(1111416)
# ic| best_fitness: np.int64(1112230)
# ic| best_fitness: np.int64(1112332)
# ic| best_fitness: np.int64(1112877)
# ic| best_fitness: np.int64(1113670)
# ic| best_fitness: np.int64(1114416)
# ic| best_fitness: np.int64(1114738)
# ic| best_fitness: np.int64(1114774)
# ic| best_fitness: np.int64(1115097)
# ic| best_fitness: np.int64(1115570)
# ic| best_fitness: np.int64(1116088)
# ic| best_fitness: np.int64(1116183)
# ic| best_fitness: np.int64(1116917)
# ic| best_fitness: np.int64(1117477)
# ic| best_fitness: np.int64(1118236)
# ic| best_fitness: np.int64(1118687)
# ic| best_fitness: np.int64(1119245)
# ic| best_fitness: np.int64(1119426)
# ic| best_fitness: np.int64(1119809)
# ic| best_fitness: np.int64(1120063)
# ic| best_fitness: np.int64(1120267)
# ic| best_fitness: np.int64(1120416)
# ic| best_fitness: np.int64(1120531)
# ic| best_fitness: np.int64(1121310)
# ic| best_fitness: np.int64(1122197)
# ic| best_fitness: np.int64(1122220)
# ic| best_fitness: np.int64(1122243)
# ic| best_fitness: np.int64(1122339)
# ic| best_fitness: np.int64(1122793)
# ic| best_fitness: np.int64(1123494)
# ic| best_fitness: np.int64(1123876)
# ic| best_fitness: np.int64(1124851)
# ic| best_fitness: np.int64(1125343)
# ic| best_fitness: np.int64(1126104)
# ic| best_fitness: np.int64(1126315)
# ic| best_fitness: np.int64(1126750)
# ic| best_fitness: np.int64(1127252)
# ic| best_fitness: np.int64(1127583)
# ic| best_fitness: np.int64(1128095)
# ic| best_fitness: np.int64(1128685)
# ic| best_fitness: np.int64(1129402)
# ic| best_fitness: np.int64(1129622)
# ic| best_fitness: np.int64(1130602)
# ic| best_fitness: np.int64(1131106)
# ic| best_fitness: np.int64(1131156)
# ic| best_fitness: np.int64(1132047)
# ic| best_fitness: np.int64(1132800)
# ic| best_fitness: np.int64(1133232)
# ic| best_fitness: np.int64(1133292)
# ic| best_fitness: np.int64(1134272)
# ic| best_fitness: np.int64(1134435)
# ic| best_fitness: np.int64(1134461)
# ic| best_fitness: np.int64(1135407)
# ic| best_fitness: np.int64(1135717)
# ic| best_fitness: np.int64(1135868)
# ic| best_fitness: np.int64(1136123)
# ic| best_fitness: np.int64(1137004)
# ic| best_fitness: np.int64(1137481)
# ic| best_fitness: np.int64(1137927)
# ic| best_fitness: np.int64(1138239)
# ic| best_fitness: np.int64(1138559)
# ic| best_fitness: np.int64(1139219)
# ic| best_fitness: np.int64(1139356)
# ic| best_fitness: np.int64(1139471)
# ic| best_fitness: np.int64(1139987)
# ic| best_fitness: np.int64(1140868)
# ic| best_fitness: np.int64(1141151)
# ic| best_fitness: np.int64(1141454)
# ic| best_fitness: np.int64(1142033)
# ic| best_fitness: np.int64(1143020)
# ic| best_fitness: np.int64(1143956)
# ic| best_fitness: np.int64(1144666)
# ic| best_fitness: np.int64(1144868)
# ic| best_fitness: np.int64(1145553)
# ic| best_fitness: np.int64(1146831)
# ic| best_fitness: np.int64(1146951)
# ic| best_fitness: np.int64(1147088)
# ic| best_fitness: np.int64(1147325)
# ic| best_fitness: np.int64(1147444)
# ic| best_fitness: np.int64(1147682)
# ic| best_fitness: np.int64(1147712)
# ic| best_fitness: np.int64(1148502)
# ic| best_fitness: np.int64(1148901)
# ic| best_fitness: np.int64(1149175)
# ic| best_fitness: np.int64(1149841)
# ic| best_fitness: np.int64(1150574)
# ic| best_fitness: np.int64(1150894)
# ic| best_fitness: np.int64(1151029)
# ic| best_fitness: np.int64(1151606)
# ic| best_fitness: np.int64(1152218)
# ic| best_fitness: np.int64(1152332)
# ic| best_fitness: np.int64(1152624)
# ic| best_fitness: np.int64(1153585)
# ic| best_fitness: np.int64(1153966)
# ic| best_fitness: np.int64(1154457)
# ic| best_fitness: np.int64(1154520)
# ic| best_fitness: np.int64(1154526)
# ic| best_fitness: np.int64(1154872)
# ic| best_fitness: np.int64(1154940)
# ic| best_fitness: np.int64(1156193)
# ic| best_fitness: np.int64(1156274)
# ic| best_fitness: np.int64(1156853)
# ic| best_fitness: np.int64(1156933)
# ic| best_fitness: np.int64(1157744)
# ic| best_fitness: np.int64(1158305)
# ic| best_fitness: np.int64(1159056)
# ic| best_fitness: np.int64(1159063)
# ic| best_fitness: np.int64(1159560)
# ic| best_fitness: np.int64(1160131)
# ic| best_fitness: np.int64(1160270)
# ic| best_fitness: np.int64(1160290)
# ic| best_fitness: np.int64(1160425)
# ic| best_fitness: np.int64(1160570)
# ic| best_fitness: np.int64(1160853)
# ic| best_fitness: np.int64(1161534)
# ic| best_fitness: np.int64(1162096)
# ic| best_fitness: np.int64(1162397)
# ic| best_fitness: np.int64(1162407)
# ic| best_fitness: np.int64(1162415)
# ic| best_fitness: np.int64(1162554)
# ic| best_fitness: np.int64(1162695)
# ic| best_fitness: np.int64(1162955)
# ic| best_fitness: np.int64(1163808)
# ic| best_fitness: np.int64(1164523)
# ic| best_fitness: np.int64(1164936)
# ic| best_fitness: np.int64(1164989)
# ic| best_fitness: np.int64(1165039)
# ic| best_fitness: np.int64(1165548)
# ic| best_fitness: np.int64(1165748)
# ic| best_fitness: np.int64(1166230)
# ic| best_fitness: np.int64(1166306)
# ic| best_fitness: np.int64(1166896)
# ic| best_fitness: np.int64(1167019)
# ic| best_fitness: np.int64(1167105)
# ic| best_fitness: np.int64(1167351)
# ic| best_fitness: np.int64(1168040)
# ic| best_fitness: np.int64(1168716)
# ic| best_fitness: np.int64(1168996)
# ic| best_fitness: np.int64(1169420)
# ic| best_fitness: np.int64(1169567)
# ic| best_fitness: np.int64(1170370)
# ic| best_fitness: np.int64(1171038)
# ic| best_fitness: np.int64(1171190)
# ic| best_fitness: np.int64(1171288)
# ic| best_fitness: np.int64(1171478)
# ic| best_fitness: np.int64(1171715)
# ic| best_fitness: np.int64(1172341)
# ic| best_fitness: np.int64(1172711)
# ic| best_fitness: np.int64(1173275)
# ic| best_fitness: np.int64(1173763)
# ic| best_fitness: np.int64(1174738)
# ic| best_fitness: np.int64(1175335)
# ic| best_fitness: np.int64(1175803)
# ic| best_fitness: np.int64(1176206)
# ic| best_fitness: np.int64(1176595)
# ic| best_fitness: np.int64(1177359)
# ic| best_fitness: np.int64(1178048)
# ic| best_fitness: np.int64(1178475)
# ic| best_fitness: np.int64(1179119)
# ic| best_fitness: np.int64(1179325)
# ic| best_fitness: np.int64(1179878)
# ic| best_fitness: np.int64(1180490)
# ic| best_fitness: np.int64(1181405)
# ic| best_fitness: np.int64(1182366)
# ic| best_fitness: np.int64(1183146)
# ic| best_fitness: np.int64(1183474)
# ic| best_fitness: np.int64(1184353)
# ic| best_fitness: np.int64(1184417)
# ic| best_fitness: np.int64(1184692)
# ic| best_fitness: np.int64(1184825)
# ic| best_fitness: np.int64(1185653)
# ic| best_fitness: np.int64(1185999)
# ic| best_fitness: np.int64(1186568)
# ic| best_fitness: np.int64(1187279)
# ic| best_fitness: np.int64(1187918)
# ic| best_fitness: np.int64(1188290)
# ic| best_fitness: np.int64(1188508)
# ic| best_fitness: np.int64(1189226)
# ic| best_fitness: np.int64(1190077)
# ic| best_fitness: np.int64(1190644)
# ic| best_fitness: np.int64(1190826)
# ic| best_fitness: np.int64(1190849)
# ic| best_fitness: np.int64(1190929)
# ic| best_fitness: np.int64(1191898)
# ic| best_fitness: np.int64(1192075)
# ic| best_fitness: np.int64(1192364)
# ic| best_fitness: np.int64(1192699)
# ic| best_fitness: np.int64(1193127)
# ic| best_fitness: np.int64(1193789)
# ic| best_fitness: np.int64(1194526)
# ic| best_fitness: np.int64(1195038)
# ic| best_fitness: np.int64(1195105)
# ic| best_fitness: np.int64(1196089)
# ic| best_fitness: np.int64(1196926)
# ic| best_fitness: np.int64(1197615)
# ic| best_fitness: np.int64(1197782)
# ic| best_fitness: np.int64(1198189)
# ic| best_fitness: np.int64(1199084)
# ic| best_fitness: np.int64(1199703)
# ic| best_fitness: np.int64(1200106)
# ic| best_fitness: np.int64(1200257)
# ic| best_fitness: np.int64(1200537)
# ic| best_fitness: np.int64(1200704)
# ic| best_fitness: np.int64(1201424)
# ic| best_fitness: np.int64(1202340)
# ic| best_fitness: np.int64(1202567)
# ic| best_fitness: np.int64(1202699)
# ic| best_fitness: np.int64(1203241)
# ic| best_fitness: np.int64(1203325)
# ic| best_fitness: np.int64(1204223)
# ic| best_fitness: np.int64(1204485)
# ic| best_fitness: np.int64(1204555)
# ic| best_fitness: np.int64(1204744)
# ic| best_fitness: np.int64(1204790)
# ic| best_fitness: np.int64(1205090)
# ic| best_fitness: np.int64(1205180)
# ic| best_fitness: np.int64(1205424)
# ic| best_fitness: np.int64(1206027)
# ic| best_fitness: np.int64(1206388)
# ic| best_fitness: np.int64(1206404)
# ic| best_fitness: np.int64(1206824)
# ic| best_fitness: np.int64(1207439)
# ic| best_fitness: np.int64(1207914)
# ic| best_fitness: np.int64(1208678)
# ic| best_fitness: np.int64(1209120)
# ic| best_fitness: np.int64(1209467)
# ic| best_fitness: np.int64(1209845)
# ic| best_fitness: np.int64(1210216)
# ic| best_fitness: np.int64(1210654)
# ic| best_fitness: np.int64(1211002)
# ic| best_fitness: np.int64(1211527)
# ic| best_fitness: np.int64(1211603)
# ic| best_fitness: np.int64(1211838)
# ic| best_fitness: np.int64(1212470)
# ic| best_fitness: np.int64(1213109)
# ic| best_fitness: np.int64(1213507)
# ic| best_fitness: np.int64(1214028)
# ic| best_fitness: np.int64(1214878)
# ic| best_fitness: np.int64(1215535)
# ic| best_fitness: np.int64(1215750)
# ic| best_fitness: np.int64(1215859)
# ic| best_fitness: np.int64(1216638)
# ic| best_fitness: np.int64(1218007)
# ic| best_fitness: np.int64(1218712)
# ic| best_fitness: np.int64(1219391)
# ic| best_fitness: np.int64(1219792)
# ic| best_fitness: np.int64(1219857)
# ic| best_fitness: np.int64(1220240)
# ic| best_fitness: np.int64(1220427)
# ic| best_fitness: np.int64(1220971)
# ic| best_fitness: np.int64(1221115)
# ic| best_fitness: np.int64(1221617)
# ic| best_fitness: np.int64(1222343)
# ic| best_fitness: np.int64(1222540)
# ic| best_fitness: np.int64(1222854)
# ic| best_fitness: np.int64(1223391)
# ic| best_fitness: np.int64(1223475)
# ic| best_fitness: np.int64(1224019)
# ic| best_fitness: np.int64(1224369)
# ic| best_fitness: np.int64(1224610)
# ic| best_fitness: np.int64(1224763)
# ic| best_fitness: np.int64(1225018)
# ic| best_fitness: np.int64(1225608)
# ic| best_fitness: np.int64(1226463)
# ic| best_fitness: np.int64(1227313)
# ic| best_fitness: np.int64(1228395)
# ic| best_fitness: np.int64(1228703)
# ic| best_fitness: np.int64(1229029)
# ic| best_fitness: np.int64(1229305)
# ic| best_fitness: np.int64(1229753)
# ic| best_fitness: np.int64(1230388)
# ic| best_fitness: np.int64(1231107)
# ic| best_fitness: np.int64(1231949)
# ic| best_fitness: np.int64(1232064)
# ic| best_fitness: np.int64(1232096)
# ic| best_fitness: np.int64(1232138)
# ic| best_fitness: np.int64(1232808)
# ic| best_fitness: np.int64(1232939)
# ic| best_fitness: np.int64(1233184)
# ic| best_fitness: np.int64(1233490)
# ic| best_fitness: np.int64(1233838)
# ic| best_fitness: np.int64(1234114)
# ic| best_fitness: np.int64(1234479)
# ic| best_fitness: np.int64(1234552)
# ic| best_fitness: np.int64(1234611)
# ic| best_fitness: np.int64(1234615)
# ic| best_fitness: np.int64(1234976)
# ic| best_fitness: np.int64(1235024)
# ic| best_fitness: np.int64(1235042)
# ic| best_fitness: np.int64(1236012)
# ic| best_fitness: np.int64(1236135)
# ic| best_fitness: np.int64(1236637)
# ic| best_fitness: np.int64(1236765)
# ic| best_fitness: np.int64(1236906)
# ic| best_fitness: np.int64(1237826)
# ic| best_fitness: np.int64(1237909)
# ic| best_fitness: np.int64(1238102)
# ic| best_fitness: np.int64(1238419)
# ic| best_fitness: np.int64(1238610)
# ic| best_fitness: np.int64(1239418)
# ic| best_fitness: np.int64(1239440)
# ic| best_fitness: np.int64(1240078)
# ic| best_fitness: np.int64(1240346)
# ic| best_fitness: np.int64(1240750)
# ic| best_fitness: np.int64(1240781)
# ic| best_fitness: np.int64(1241043)
# ic| best_fitness: np.int64(1241086)
# ic| best_fitness: np.int64(1241378)
# ic| best_fitness: np.int64(1242339)
# ic| best_fitness: np.int64(1242357)
# ic| best_fitness: np.int64(1243096)
# ic| best_fitness: np.int64(1243438)
# ic| best_fitness: np.int64(1243696)
# ic| best_fitness: np.int64(1244403)
# ic| best_fitness: np.int64(1244629)
# ic| best_fitness: np.int64(1245625)
# ic| best_fitness: np.int64(1246549)
# ic| best_fitness: np.int64(1246815)
# ic| best_fitness: np.int64(1247429)
# ic| best_fitness: np.int64(1248067)
# ic| best_fitness: np.int64(1248730)
# ic| best_fitness: np.int64(1248850)
# ic| best_fitness: np.int64(1249415)
# ic| best_fitness: np.int64(1249557)
# ic| best_fitness: np.int64(1249660)
# ic| best_fitness: np.int64(1250120)
# ic| best_fitness: np.int64(1250359)
# ic| best_fitness: np.int64(1250473)
# ic| best_fitness: np.int64(1250553)
# ic| best_fitness: np.int64(1250817)
# ic| best_fitness: np.int64(1251625)
# ic| best_fitness: np.int64(1252102)
# ic| best_fitness: np.int64(1252706)
# ic| best_fitness: np.int64(1253227)
# ic| best_fitness: np.int64(1253234)
# ic| best_fitness: np.int64(1253720)
# ic| best_fitness: np.int64(1254187)
# ic| best_fitness: np.int64(1254245)
# ic| best_fitness: np.int64(1254254)
# ic| best_fitness: np.int64(1254579)
# ic| best_fitness: np.int64(1254643)
# ic| best_fitness: np.int64(1255203)
# ic| best_fitness: np.int64(1255228)
# ic| best_fitness: np.int64(1255648)
# ic| best_fitness: np.int64(1256344)
# ic| best_fitness: np.int64(1256512)
# ic| best_fitness: np.int64(1257124)
# ic| best_fitness: np.int64(1257369)
# ic| best_fitness: np.int64(1258247)
# ic| best_fitness: np.int64(1258254)
# ic| best_fitness: np.int64(1258327)
# ic| best_fitness: np.int64(1258875)
# ic| best_fitness: np.int64(1259099)
# ic| best_fitness: np.int64(1259333)
# ic| best_fitness: np.int64(1260065)
# ic| best_fitness: np.int64(1260159)
# ic| best_fitness: np.int64(1260663)
# ic| best_fitness: np.int64(1261200)
# ic| best_fitness: np.int64(1261482)
# ic| best_fitness: np.int64(1262260)
# ic| best_fitness: np.int64(1262584)
# ic| best_fitness: np.int64(1263400)
# ic| best_fitness: np.int64(1263610)
# ic| best_fitness: np.int64(1263734)
# ic| best_fitness: np.int64(1264730)
# ic| best_fitness: np.int64(1265625)
# ic| best_fitness: np.int64(1266022)
# ic| best_fitness: np.int64(1266157)
# ic| best_fitness: np.int64(1266843)
# ic| best_fitness: np.int64(1267096)
# ic| best_fitness: np.int64(1267371)
# ic| best_fitness: np.int64(1267859)
# ic| best_fitness: np.int64(1268495)
# ic| best_fitness: np.int64(1268967)
# ic| best_fitness: np.int64(1269305)
# ic| best_fitness: np.int64(1269891)
# ic| best_fitness: np.int64(1269953)
# ic| best_fitness: np.int64(1270440)
# ic| best_fitness: np.int64(1271342)
# ic| best_fitness: np.int64(1272024)
# ic| best_fitness: np.int64(1272119)
# ic| best_fitness: np.int64(1272415)
# ic| best_fitness: np.int64(1273197)
# ic| best_fitness: np.int64(1273323)
# ic| best_fitness: np.int64(1273738)
# ic| best_fitness: np.int64(1274546)
# ic| best_fitness: np.int64(1275265)
# ic| best_fitness: np.int64(1275598)
# ic| best_fitness: np.int64(1276079)
# ic| best_fitness: np.int64(1276131)
# ic| best_fitness: np.int64(1276526)
# ic| best_fitness: np.int64(1277501)
# ic| best_fitness: np.int64(1277799)
# ic| best_fitness: np.int64(1277902)
# ic| best_fitness: np.int64(1278612)
# ic| best_fitness: np.int64(1279043)
# ic| best_fitness: np.int64(1279372)
# ic| best_fitness: np.int64(1280076)
# ic| best_fitness: np.int64(1280195)
# ic| best_fitness: np.int64(1280725)
# ic| best_fitness: np.int64(1281335)
# ic| best_fitness: np.int64(1281905)
# ic| best_fitness: np.int64(1282321)
# ic| best_fitness: np.int64(1282858)
# ic| best_fitness: np.int64(1283116)
# ic| best_fitness: np.int64(1283143)
# ic| best_fitness: np.int64(1283166)
# ic| best_fitness: np.int64(1283885)
# ic| best_fitness: np.int64(1284040)
# ic| best_fitness: np.int64(1284222)
# ic| best_fitness: np.int64(1284754)
# ic| best_fitness: np.int64(1284938)
# ic| best_fitness: np.int64(1285027)
# ic| best_fitness: np.int64(1285825)
# ic| best_fitness: np.int64(1286604)
# ic| best_fitness: np.int64(1286735)
# ic| best_fitness: np.int64(1287057)
# ic| best_fitness: np.int64(1287172)
# ic| best_fitness: np.int64(1287307)
# ic| best_fitness: np.int64(1287730)
# ic| best_fitness: np.int64(1287775)
# ic| best_fitness: np.int64(1288684)
# ic| best_fitness: np.int64(1289115)
# ic| best_fitness: np.int64(1289961)
# ic| best_fitness: np.int64(1290409)
# ic| best_fitness: np.int64(1290678)
# ic| best_fitness: np.int64(1290905)
# ic| best_fitness: np.int64(1291902)
# ic| best_fitness: np.int64(1292070)
# ic| best_fitness: np.int64(1292269)
# ic| best_fitness: np.int64(1292373)
# ic| best_fitness: np.int64(1292861)
# ic| best_fitness: np.int64(1292973)
# ic| best_fitness: np.int64(1293941)
# ic| best_fitness: np.int64(1293943)
# ic| best_fitness: np.int64(1293966)
# ic| best_fitness: np.int64(1294281)
# ic| best_fitness: np.int64(1294973)
# ic| best_fitness: np.int64(1295113)
# ic| best_fitness: np.int64(1295805)
# ic| best_fitness: np.int64(1296595)
# ic| best_fitness: np.int64(1297086)
# ic| best_fitness: np.int64(1297185)
# ic| best_fitness: np.int64(1297379)
# ic| best_fitness: np.int64(1298165)
# True
